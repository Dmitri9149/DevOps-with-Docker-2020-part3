# %% [markdown]
# <a href="https://colab.research.google.com/github/Dmitri9149/DevOps-with-Docker-2020-part3/blob/master/Kubernets_picture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Kubernets picture

# %%
from IPython.display import Image
Image("/content/drive/My Drive/Data/Kubernetes_v5.png", width = 800)
